# %% [markdown]
# first time, go to 'https://github.com/[yourgithubusername]/Data102_Final_Project.git/' and permit it access to ur account. then run the cell below, click on the link, and paste (a key is copied to ur keyboard). u should now be able to git commit.

# %%
import gh_scoped_creds
# %ghscopedcreds
# Out:
# The code EC98-EB23 has been copied to your clipboard.
# You have 15 minutes to go to https://github.com/login/device and paste it there.
#
# Waiting.....
# <p style="background-color:lightgreen;">Success! Authentication will expire in 8.0 hours.<br /></p>
# Visit https://github.com/apps/data102-datahub-access to manage list of repositories you can push to from this location
# Tip: Use https:// URLs to clone and push to repos, not ssh URLs!
